# %% [markdown]
# # 06 - Cross-Representation Comparison
#
# Run only after both representations independently froze their final models (k=4 metadata, k=8 full text).

# %%
import subprocess, sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PY = str(ROOT / '..' / '.venv' / 'Scripts' / 'python.exe')
def run(*args):
    print('$', *args)
    subprocess.run([PY, *args], cwd=ROOT, check=True)

# %%
run('src/cross_representation.py', '4', '14', '8', '2', '5', '0.50', '4', '0.75')

# %% [markdown]
# Output: `results/cross_representation/`, `reports/CROSS_REPRESENTATION_REPORT.md`.
