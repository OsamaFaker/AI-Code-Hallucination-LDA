# %% [markdown]
# # 01 - Corpus Audit
#
# Builds and validates the 66-primary-study manifest from the master reference spreadsheet and the PDF folders. Thin wrapper around the tested `src/` scripts - see `README.md` for the full documented pipeline.

# %%
import subprocess, sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PY = str(ROOT / '..' / '.venv' / 'Scripts' / 'python.exe')
def run(*args):
    print('$', *args)
    subprocess.run([PY, *args], cwd=ROOT, check=True)

# %%
run('src/corpus_audit.py')

# %% [markdown]
# Output: `corpus/primary_studies_manifest.csv`, `corpus/corpus_audit.md`.
